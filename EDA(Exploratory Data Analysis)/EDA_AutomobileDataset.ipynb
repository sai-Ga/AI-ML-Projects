# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df_automobile = pd.read_csv(r'/content/Automobile_data.csv')
df_automobile.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
for col in df_automobile:
  print("column number:",col)
  print(df_automobile[col].value_counts())
  print(' ')
# Out:
# column number: symboling
# symboling
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: count, dtype: int64
#
# column number: normalized-losses
# normalized-losses
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: count, dtype: int64
#
# column number: make
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: count, dtype: int64
#
# column number: fuel-type
# fuel-type
# gas       185
# diesel     20
# Name: count, dtype: int64
#
# column number: aspiration
# aspiration
# std      168
# turbo     37
# Name: count, dtype: int64
#
# column number: num-of-doors
# num-of-doors
# four    114
# two      89
# ?         2
# Name: count, dtype: int64
#
# column number: body-style
# body-style
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64
#
# column number: drive-wheels
# drive-wheels
# fwd    120
# rwd     76
# 4wd      9
# Name: count, dtype: int64
#
# column number: engine-location
# engine-location
# front    202
# rear       3
# Name: count, dtype: int64
#
# column number: wheel-base
# wheel-base
# 94.5     21
# 93.7     20
# 95.7     13
# 96.5      8
# 97.3      7
# 98.4      7
# 104.3     6
# 100.4     6
# 107.9     6
# 98.8      6
# 99.1      6
# 96.3      6
# 109.1     5
# 93.1      5
# 97.2      5
# 95.9      5
# 102.4     5
# 97.0      4
# 95.3      4
# 114.2     4
# 101.2     4
# 110.0     3
# 103.5     3
# 89.5      3
# 105.8     3
# 96.1      2
# 102.9     2
# 104.5     2
# 91.3      2
# 96.9      2
# 88.6      2
# 113.0     2
# 99.8      2
# 115.6     2
# 103.3     2
# 86.6      2
# 104.9     2
# 93.3      1
# 99.4      1
# 99.5      1
# 88.4      1
# 94.3      1
# 96.0      1
# 95.1      1
# 93.0      1
# 102.0     1
# 106.7     1
# 108.0     1
# 96.6      1
# 99.2      1
# 112.0     1
# 102.7     1
# 120.9     1
# Name: count, dtype: int64
#
# column number: length
# length
# 157.3    15
# 188.8    11
# 171.7     7
# 186.7     7
# 166.3     7
#          ..
# 165.6     1
# 187.5     1
# 180.3     1
# 208.1     1
# 199.2     1
# Name: count, Length: 75, dtype: int64
#
# column number: width
# width
# 63.8    24
# 66.5    23
# 65.4    15
# 63.6    11
# 64.4    10
# 68.4    10
# 64.0     9
# 65.5     8
# 65.2     7
# 64.2     6
# 66.3     6
# 65.6     6
# 67.2     6
# 67.9     5
# 66.9     5
# 65.7     4
# 68.9     4
# 64.8     4
# 63.9     3
# 70.3     3
# 71.7     3
# 71.4     3
# 65.0     3
# 68.3     2
# 67.7     2
# 64.1     2
# 66.1     2
# 69.6     2
# 64.6     2
# 72.0     1
# 68.0     1
# 70.5     1
# 61.8     1
# 66.0     1
# 62.5     1
# 70.6     1
# 72.3     1
# 66.6     1
# 63.4     1
# 60.3     1
# 70.9     1
# 66.4     1
# 66.2     1
# 68.8     1
# Name: count, dtype: int64
#
# column number: height
# height
# 50.8    14
# 52.0    12
# 55.7    12
# 54.1    10
# 54.5    10
# 55.5     9
# 56.7     8
# 54.3     8
# 52.6     7
# 56.1     7
# 51.6     7
# 53.0     6
# 52.8     6
# 54.9     6
# 50.2     6
# 53.7     5
# 55.1     5
# 50.6     5
# 49.6     4
# 58.7     4
# 53.3     4
# 52.5     3
# 59.1     3
# 56.2     3
# 49.7     3
# 57.5     3
# 53.5     3
# 54.4     2
# 53.9     2
# 56.3     2
# 50.5     2
# 59.8     2
# 56.5     2
# 54.7     2
# 48.8     2
# 49.4     2
# 51.4     2
# 51.0     1
# 54.8     1
# 55.4     1
# 56.0     1
# 55.2     1
# 53.2     1
# 47.8     1
# 55.9     1
# 52.4     1
# 55.6     1
# 53.1     1
# 58.3     1
# Name: count, dtype: int64
#
# column number: curb-weight
# curb-weight
# 2385    4
# 1918    3
# 2275    3
# 1989    3
# 2410    2
#        ..
# 2370    1
# 2328    1
# 2833    1
# 2921    1
# 3062    1
# Name: count, Length: 171, dtype: int64
#
# column number: engine-type
# engine-type
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: count, dtype: int64
#
# column number: num-of-cylinders
# num-of-cylinders
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: count, dtype: int64
#
# column number: engine-size
# engine-size
# 122    15
# 92     15
# 97     14
# 98     14
# 108    13
# 90     12
# 110    12
# 109     8
# 120     7
# 141     7
# 152     6
# 181     6
# 146     6
# 121     6
# 156     5
# 136     5
# 91      5
# 183     4
# 130     4
# 171     3
# 70      3
# 194     3
# 209     3
# 164     3
# 258     2
# 140     2
# 134     2
# 234     2
# 132     2
# 131     2
# 173     1
# 203     1
# 161     1
# 80      1
# 151     1
# 103     1
# 304     1
# 308     1
# 326     1
# 119     1
# 111     1
# 79      1
# 61      1
# 145     1
# Name: count, dtype: int64
#
# column number: fuel-system
# fuel-system
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: count, dtype: int64
#
# column number: bore
# bore
# 3.62    23
# 3.19    20
# 3.15    15
# 3.03    12
# 2.97    12
# 3.46     9
# 3.31     8
# 3.78     8
# 3.43     8
# 3.27     7
# 2.91     7
# 3.39     6
# 3.54     6
# 3.05     6
# 3.58     6
# 3.7      5
# 3.01     5
# 3.35     4
# ?        4
# 3.17     3
# 3.59     3
# 3.74     3
# 3.47     2
# 3.94     2
# 3.24     2
# 3.13     2
# 3.63     2
# 3.5      2
# 3.8      2
# 3.33     2
# 2.54     1
# 3.08     1
# 3.61     1
# 3.34     1
# 3.6      1
# 2.92     1
# 3.76     1
# 2.68     1
# 2.99     1
# Name: count, dtype: int64
#
# column number: stroke
# stroke
# 3.4     20
# 3.23    14
# 3.15    14
# 3.03    14
# 3.39    13
# 2.64    11
# 3.29     9
# 3.35     9
# 3.46     8
# 3.11     6
# 3.27     6
# 3.41     6
# 3.07     6
# 3.58     6
# 3.19     6
# 3.5      6
# 3.64     5
# 3.52     5
# 3.86     4
# 3.54     4
# 3.47     4
# ?        4
# 3.9      3
# 2.9      3
# 3.1      2
# 4.17     2
# 2.8      2
# 2.19     2
# 3.08     2
# 2.68     2
# 2.36     1
# 3.16     1
# 2.07     1
# 3.21     1
# 3.12     1
# 2.76     1
# 2.87     1
# Name: count, dtype: int64
#
# column number: compression-ratio
# compression-ratio
# 9.00     46
# 9.40     26
# 8.50     14
# 9.50     13
# 9.30     11
# 8.70      9
# 8.00      8
# 9.20      8
# 7.00      7
# 8.60      5
# 21.00     5
# 8.40      5
# 7.50      5
# 23.00     5
# 9.60      5
# 21.50     4
# 7.60      4
# 10.00     3
# 22.50     3
# 8.30      3
# 8.80      3
# 7.70      2
# 8.10      2
# 9.10      1
# 9.31      1
# 7.80      1
# 9.41      1
# 21.90     1
# 22.00     1
# 22.70     1
# 10.10     1
# 11.50     1
# Name: count, dtype: int64
#
# column number: horsepower
# horsepower
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 88      6
# 62      6
# 101     6
# 160     6
# 114     6
# 84      5
# 97      5
# 102     5
# 145     5
# 82      5
# 76      5
# 111     4
# 92      4
# 123     4
# 86      4
# 90      3
# 73      3
# 85      3
# 207     3
# 182     3
# 121     3
# 152     3
# 112     2
# 56      2
# 161     2
# 156     2
# 94      2
# 52      2
# ?       2
# 162     2
# 155     2
# 184     2
# 100     2
# 176     2
# 55      1
# 262     1
# 134     1
# 115     1
# 140     1
# 48      1
# 58      1
# 60      1
# 78      1
# 135     1
# 200     1
# 64      1
# 120     1
# 72      1
# 154     1
# 288     1
# 143     1
# 142     1
# 175     1
# 106     1
# Name: count, dtype: int64
#
# column number: peak-rpm
# peak-rpm
# 5500    37
# 4800    36
# 5000    27
# 5200    23
# 5400    13
# 6000     9
# 5250     7
# 4500     7
# 5800     7
# 4200     5
# 4150     5
# 4750     4
# 4350     4
# 5100     3
# 4250     3
# 5900     3
# 4400     3
# ?        2
# 6600     2
# 4650     1
# 5600     1
# 5750     1
# 4900     1
# 5300     1
# Name: count, dtype: int64
#
# column number: city-mpg
# city-mpg
# 31    28
# 19    27
# 24    22
# 27    14
# 17    13
# 26    12
# 23    12
# 21     8
# 25     8
# 30     8
# 38     7
# 28     7
# 16     6
# 37     6
# 22     4
# 29     3
# 15     3
# 20     3
# 18     3
# 14     2
# 34     1
# 35     1
# 32     1
# 36     1
# 45     1
# 13     1
# 49     1
# 47     1
# 33     1
# Name: count, dtype: int64
#
# column number: highway-mpg
# highway-mpg
# 25    19
# 38    17
# 24    17
# 30    16
# 32    16
# 34    14
# 37    13
# 28    13
# 29    10
# 33     9
# 22     8
# 31     8
# 23     7
# 27     5
# 43     4
# 42     3
# 26     3
# 41     3
# 19     2
# 39     2
# 18     2
# 16     2
# 20     2
# 36     2
# 47     2
# 46     2
# 54     1
# 17     1
# 53     1
# 50     1
# Name: count, dtype: int64
#
# column number: price
# price
# ?        4
# 8921     2
# 18150    2
# 8845     2
# 8495     2
#         ..
# 45400    1
# 16503    1
# 5389     1
# 6189     1
# 22625    1
# Name: count, Length: 187, dtype: int64

# %%
df_automobile = df_automobile.replace('?',np.NAN)
df_automobile.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
df_automobile.isnull().any().any()
# Out:
# True

# %%
df_automobile.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# Function that replaces all the NAN values with mean (only for float dtype)

def replace_nan_with_mean(df, columns, verbose=False):
    for column in columns:
        avg_value = df[column].astype("float").mean(axis=0)
        df[column].fillna(avg_value, inplace=True)
        if verbose:
            print(f"Average of {column}: {avg_value}")
    return df


columns_to_process = ["normalized-losses","stroke", "horsepower", "peak-rpm","bore"]
df_automobile = replace_nan_with_mean(df_automobile, columns_to_process, verbose=True)
# Out:
# Average of normalized-losses: 122.0
# Average of stroke: 3.255422885572139
# Average of horsepower: 104.25615763546799
# Average of peak-rpm: 5125.369458128079
# Average of bore: 3.3297512437810943

# %%
df_automobile['num-of-doors'].value_counts()
# Out:
# num-of-doors
# four    114
# two      89
# Name: count, dtype: int64

# %%
df_automobile['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
df_automobile['num-of-doors'].replace(np.NAN,'four',inplace=True)
df_automobile.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
before_rows = df_automobile.shape[0]
df_automobile.dropna(subset=['price'],axis =0,inplace=True)
after_rows = df_automobile.shape[0]
print('Number of Dropped Rows{}'.format(before_rows - after_rows))
df_automobile.reset_index(drop=True)
# Out:
# Number of Dropped Rows4
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 196         -1                95        volvo       gas        std
# 197         -1                95        volvo       gas      turbo
# 198         -1                95        volvo       gas        std
# 199         -1                95        volvo    diesel      turbo
# 200         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 196         four        sedan          rwd           front       109.1  ...
# 197         four        sedan          rwd           front       109.1  ...
# 198         four        sedan          rwd           front       109.1  ...
# 199         four        sedan          rwd           front       109.1  ...
# 200         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            152         mpfi  2.68    3.47               9.0        154
# 3            109         mpfi  3.19     3.4              10.0        102
# 4            136         mpfi  3.19     3.4               8.0        115
# ..           ...          ...   ...     ...               ...        ...
# 196          141         mpfi  3.78    3.15               9.5        114
# 197          141         mpfi  3.78    3.15               8.7        160
# 198          173         mpfi  3.58    2.87               8.8        134
# 199          145          idi  3.01     3.4              23.0        106
# 200          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  13495
# 1        5000       21          27  16500
# 2        5000       19          26  16500
# 3        5500       24          30  13950
# 4        5500       18          22  17450
# ..        ...      ...         ...    ...
# 196      5400       23          28  16845
# 197      5300       19          25  19045
# 198      5500       18          23  21485
# 199      4800       26          27  22470
# 200      5400       19          25  22625
#
# [201 rows x 26 columns]

# %%
df_automobile.shape
# Out:
# (201, 26)

# %%
df_automobile.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df_automobile[['bore','stroke']] = df_automobile[['bore','stroke']].astype('float')

df_automobile[['normalized-losses']] = df_automobile[['normalized-losses']].astype('int')

df_automobile[['price']] = df_automobile[['price']].astype('float')

df_automobile[['peak-rpm']] = df_automobile[['peak-rpm']].astype('float')

df_automobile.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak-rpm city-mpg  highway-mpg    price
# 0    5000.0       21           27  13495.0
# 1    5000.0       21           27  16500.0
# 2    5000.0       19           26  16500.0
# 3    5500.0       24           30  13950.0
# 4    5500.0       18           22  17450.0
#
# [5 rows x 26 columns]

# %%
df_automobile['highway-mpg'] = 235/df_automobile['highway-mpg']
df_automobile.rename(columns={'highway=mpg':'highway-L/100km'},inplace=True)
df_automobile.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak-rpm city-mpg  highway-mpg    price
# 0    5000.0       21     8.703704  13495.0
# 1    5000.0       21     8.703704  16500.0
# 2    5000.0       19     9.038462  16500.0
# 3    5500.0       24     7.833333  13950.0
# 4    5500.0       18    10.681818  17450.0
#
# [5 rows x 26 columns]

# %%
df_automobile['lenght'] = df_automobile['length']/df_automobile['length'].max()
df_automobile['lenght'] = df_automobile['width']/df_automobile['width'].max()
df_automobile.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0         mpfi  3.47    2.68                9.0        111   5000.0        21
# 1         mpfi  3.47    2.68                9.0        111   5000.0        21
# 2         mpfi  2.68    3.47                9.0        154   5000.0        19
# 3         mpfi  3.19    3.40               10.0        102   5500.0        24
# 4         mpfi  3.19    3.40                8.0        115   5500.0        18
#
#   highway-mpg    price    lenght
# 0    8.703704  13495.0  0.890278
# 1    8.703704  16500.0  0.890278
# 2    9.038462  16500.0  0.909722
# 3    7.833333  13950.0  0.919444
# 4   10.681818  17450.0  0.922222
#
# [5 rows x 27 columns]

# %%
df_automobile['lenght'] = df_automobile['height']/df_automobile['height'].max()
df_automobile.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0         mpfi  3.47    2.68                9.0        111   5000.0        21
# 1         mpfi  3.47    2.68                9.0        111   5000.0        21
# 2         mpfi  2.68    3.47                9.0        154   5000.0        19
# 3         mpfi  3.19    3.40               10.0        102   5500.0        24
# 4         mpfi  3.19    3.40                8.0        115   5500.0        18
#
#   highway-mpg    price    lenght
# 0    8.703704  13495.0  0.816054
# 1    8.703704  16500.0  0.816054
# 2    9.038462  16500.0  0.876254
# 3    7.833333  13950.0  0.908027
# 4   10.681818  17450.0  0.908027
#
# [5 rows x 27 columns]

# %%
df_automobile['horsepower'] = df_automobile['horsepower'].astype(int,copy=True)
df_automobile.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0         mpfi  3.47    2.68                9.0        111   5000.0        21
# 1         mpfi  3.47    2.68                9.0        111   5000.0        21
# 2         mpfi  2.68    3.47                9.0        154   5000.0        19
# 3         mpfi  3.19    3.40               10.0        102   5500.0        24
# 4         mpfi  3.19    3.40                8.0        115   5500.0        18
#
#   highway-mpg    price    lenght
# 0    8.703704  13495.0  0.816054
# 1    8.703704  16500.0  0.816054
# 2    9.038462  16500.0  0.876254
# 3    7.833333  13950.0  0.908027
# 4   10.681818  17450.0  0.908027
#
# [5 rows x 27 columns]

# %%
#%matplotlib inline
plt.hist(df_automobile['horsepower'])

plt.xlabel('horsepower')
plt.ylabel('counts')
plt.title('horsepower bins')
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
bins = np.linspace(min(df_automobile['horsepower']),max(df_automobile['horsepower']),4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names = ['Low','Medium','High']

df_automobile['horsepower-binned'] = pd.cut(df_automobile['horsepower'],bins,labels=group_names,include_lowest=True)
df_automobile[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0          111               Low
# 1          111               Low
# 2          154            Medium
# 3          102               Low
# 4          115               Low
# 5          110               Low
# 6          110               Low
# 7          110               Low
# 8          140            Medium
# 10         101               Low
# 11         101               Low
# 12         121            Medium
# 13         121            Medium
# 14         121            Medium
# 15         182            Medium
# 16         182            Medium
# 17         182            Medium
# 18          48               Low
# 19          70               Low
# 20          70               Low

# %%
df_automobile['horsepower-binned'].value_counts()
# Out:
# horsepower-binned
# Low       153
# Medium     43
# High        5
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(group_names, df_automobile["horsepower-binned"].value_counts())

plt.xlabel("Horsepower")
plt.ylabel("Count")
plt.title("Horsepower Bins")
# Out:
# Text(0.5, 1.0, 'Horsepower Bins')

# %%
import matplotlib.pyplot as plt
a = (0,1,2)
plt.hist(df_automobile['horsepower'],bins=3)

plt.xlabel("Horsepower")
plt.ylabel("Count")
plt.title("Horsepower Bins")
plt.show()

# %%
df_automobile.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'lenght', 'horsepower-binned'],
#       dtype='object')

# %%
dummy_variable_1 = pd.get_dummies(df_automobile['fuel-type'])
dummy_variable_1.head()
# Out:
#    diesel   gas
# 0   False  True
# 1   False  True
# 2   False  True
# 3   False  True
# 4   False  True

# %%
dummy_variable_1.rename(columns={'fuel-type-diesel':'gas','fuel-type-diesel':'diesel'},inplace=True)
dummy_variable_1.head()
# Out:
#    diesel   gas
# 0   False  True
# 1   False  True
# 2   False  True
# 3   False  True
# 4   False  True

# %%
df_automobile = pd.concat([df_automobile,dummy_variable_1],axis = 1)
df_automobile.drop('fuel-type',axis = 1,inplace=True)

# %%
dummy_variable_2 =pd.get_dummies(df_automobile['aspiration'])
dummy_variable_2.rename(columns={'std':'aspiration-std','turbo':'aspiration-turbo'},inplace=True)
dummy_variable_2.head()
# Out:
#    aspiration-std  aspiration-turbo
# 0            True             False
# 1            True             False
# 2            True             False
# 3            True             False
# 4            True             False

# %%
df_automobile = pd.concat([df_automobile,dummy_variable_2],axis = 1)
df_automobile.drop('aspiration',axis = 1,inplace=True)

# %%
df_automobile.head()
# Out:
#    symboling  normalized-losses         make num-of-doors   body-style  \
# 0          3                122  alfa-romero          two  convertible
# 1          3                122  alfa-romero          two  convertible
# 2          1                122  alfa-romero          two    hatchback
# 3          2                164         audi         four        sedan
# 4          2                164         audi         four        sedan
#
#   drive-wheels engine-location  wheel-base  length  width  ...  peak-rpm  \
# 0          rwd           front        88.6   168.8   64.1  ...    5000.0
# 1          rwd           front        88.6   168.8   64.1  ...    5000.0
# 2          rwd           front        94.5   171.2   65.5  ...    5000.0
# 3          fwd           front        99.8   176.6   66.2  ...    5500.0
# 4          4wd           front        99.4   176.6   66.4  ...    5500.0
#
#    city-mpg highway-mpg    price    lenght horsepower-binned  diesel   gas  \
# 0        21    8.703704  13495.0  0.816054               Low   False  True
# 1        21    8.703704  16500.0  0.816054               Low   False  True
# 2        19    9.038462  16500.0  0.876254            Medium   False  True
# 3        24    7.833333  13950.0  0.908027               Low   False  True
# 4        18   10.681818  17450.0  0.908027               Low   False  True
#
#    aspiration-std  aspiration-turbo
# 0            True             False
# 1            True             False
# 2            True             False
# 3            True             False
# 4            True             False
#
# [5 rows x 30 columns]

# %%
df_automobile.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015  174.200995   65.889055
# std      1.254802           31.99625    6.066366   12.322175    2.101471
# min     -2.000000           65.00000   86.600000  141.100000   60.300000
# 25%      0.000000          101.00000   94.500000  166.800000   64.100000
# 50%      1.000000          122.00000   97.000000  173.200000   65.500000
# 75%      2.000000          137.00000  102.400000  183.500000   66.600000
# max      3.000000          256.00000  120.900000  208.100000   72.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256874
# std      2.447822   517.296727    41.546834    0.268072    0.316048
# min     47.800000  1488.000000    61.000000    2.540000    2.070000
# 25%     52.000000  2169.000000    98.000000    3.150000    3.110000
# 50%     54.100000  2414.000000   120.000000    3.310000    3.290000
# 75%     55.500000  2926.000000   141.000000    3.580000    3.410000
# max     59.800000  4066.000000   326.000000    3.940000    4.170000
#
#        compression-ratio  horsepower     peak-rpm    city-mpg  highway-mpg  \
# count         201.000000  201.000000   201.000000  201.000000   201.000000
# mean           10.164279  103.402985  5117.665368   25.179104     8.044957
# std             4.004965   37.365650   478.113805    6.423220     1.840739
# min             7.000000   48.000000  4150.000000   13.000000     4.351852
# 25%             8.600000   70.000000  4800.000000   19.000000     6.911765
# 50%             9.000000   95.000000  5125.369458   24.000000     7.833333
# 75%             9.400000  116.000000  5500.000000   30.000000     9.400000
# max            23.000000  262.000000  6600.000000   49.000000    14.687500
#
#               price      lenght
# count    201.000000  201.000000
# mean   13207.129353    0.899108
# std     7947.066342    0.040933
# min     5118.000000    0.799331
# 25%     7775.000000    0.869565
# 50%    10295.000000    0.904682
# 75%    16500.000000    0.928094
# max    45400.000000    1.000000

# %%
df_automobile.to_csv(r'/content/clean_Automobile_data.csv')
